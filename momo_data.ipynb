# %%
import pandas as pd
from bs4 import BeautifulSoup
import json
import requests
import re

# %%
keyword = '抽取衛生紙'
pages = 2
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'}
urls = []
for page in range(1, pages):
    url = 'https://m.momoshop.com.tw/search.momo?_advFirst=N&_advCp=N&curPage={}&searchType=1&cateLevel=2&ent=k&searchKeyword={}&_advThreeHours=N&_isFuzzy=0&_imgSH=fourCardType'.format(page, keyword)
    print(url)
    resp = requests.get(url, headers=headers)
    if resp.status_code == 200:
        soup = BeautifulSoup(resp.text, 'html5lib')
        for item in soup.select('li.goodsItemLi > a'):
            urls.append('https://m.momoshop.com.tw'+item['href'])
    urls = list(set(urls))
    print(len(urls))
#     break
# Out:
# https://m.momoshop.com.tw/search.momo?_advFirst=N&_advCp=N&curPage=1&searchType=1&cateLevel=2&ent=k&searchKeyword=抽取衛生紙&_advThreeHours=N&_isFuzzy=0&_imgSH=fourCardType
# 20

# %%
df = []
for i, url in enumerate(urls):
    columns = []
    values = []
    
    resp = requests.get(url, headers=headers)
    soup = BeautifulSoup(resp.text)
    # 標題
    title = soup.find('meta',{'property':'og:title'})['content']
    # 品牌
    brand = soup.find('meta',{'property':'product:brand'})['content']
    # 連結
#     link = soup.find('meta',{'property':'og:url'})['content']
    # 原價
    try:
        price = re.sub(r'\r\n| ','',soup.find('del').text)
    except:
        price = ''
    # 特價
    amount = soup.find('meta',{'property':'product:price:amount'})['content']

    print('==================  {}  =================='.format(i))    
    print(title)
    print(brand)
#     print(link)
    print(amount)
    
    columns += ['title', 'brand', 'price', 'amount']
    values += [title, brand, price, amount]

    # 規格
#     for i in soup.select('div.attributesArea > table > tr'):
#         try:
#             column = i.find('th').text
#             column = re.sub('\n|\r| ','',column)
#             value = ''.join([j.text for j in i.findAll('li')])
#             value = re.sub('\n|\r| ','',value)
#             columns.append(column)
#             values.append(value)
#         except:
#             pass
    ndf = pd.DataFrame(data=values, index=columns).T
    df.append(ndf)
df=pd.concat(df, ignore_index=True)
# Out:
# ==================  0  ==================
# 【櫻花】超值新柔感抽取式衛生紙(150抽x84包/箱)
#
# 799
# ==================  1  ==================
# 【朵舒】超厚柔棉仔紙抽取式衛生紙(150抽x12包x6袋/箱)
# 朵舒
# 759
# ==================  2  ==================
# 【MAY FLOWER 五月花】新柔韌抽取式衛生紙(130抽x12包x6袋)
# MAY FLOWER 五月花
# 869
# ==================  3  ==================
# 【Kleenex 舒潔】棉柔舒適抽取衛生紙110抽X72包
# Kleenex 舒潔
# 955
# ==================  4  ==================
# 【倍潔雅】花漾柔感抽取式衛生紙(150抽70包/箱)
# PASEO 倍潔雅
# 749
# ==================  5  ==================
# 【Kleenex 舒潔】柔韌潔淨抽取衛生紙 110抽x48包/箱
# Kleenex 舒潔
# 619
# ==================  6  ==================
# 【五月花】新柔韌抽取式衛生紙(110抽x12包x6袋)
# MAY FLOWER 五月花
# 869
# ==================  7  ==================
# 【春風】抽取式衛生紙-輕柔膚觸-100抽*24包*3串
# 春風
# 679
# ==================  8  ==================
# 【朵舒】極細柔抽取式花紋衛生紙(200抽x12包x4袋/箱)
# 朵舒
# 669
# ==================  9  ==================
# 【倍潔雅】花漾柔感抽取式衛生紙(150抽84包/箱)
# PASEO 倍潔雅
# 859
# ==================  10  ==================
# 【Kleenex 舒潔】柔韌潔淨抽取衛生紙 100抽x60包/箱
# Kleenex 舒潔
# 689
# ==================  11  ==================
# 【Kirkland Signature 科克蘭】三層抽取衛生紙 120張x24包x3串/箱
# Kirkland Signature 科克蘭
# 1,359
# ==================  12  ==================
# 【倍潔雅】好韌真3層抽取式衛生紙PEFC(100抽12包6袋/箱)
# PASEO 倍潔雅
# 759
# ==================  13  ==================
# 【倍潔雅】花漾柔感抽取式衛生紙200抽x48包/箱
# PASEO 倍潔雅
# 689
# ==================  14  ==================
# 【朵舒】舒適柔抽取式衛生紙(150抽x10包x8袋/箱)
# 朵舒
# 829
# ==================  15  ==================
# 【Kleenex 舒潔】頂級三層舒適竹炭萃取抽取衛生紙 90抽x30包/箱
# Kleenex 舒潔
# 525
# ==================  16  ==================
# 【倍潔雅】柔軟舒適抽取式衛生紙150抽x60包/箱
# PASEO 倍潔雅
# 629
# ==================  17  ==================
# 【Kleenex 舒潔】絲絨舒膚抽取衛生紙110抽x64包/箱
# Kleenex 舒潔
# 789
# ==================  18  ==================
# 【五月花】花園版抽取式衛生紙(100抽*8包*8袋)
# MAY FLOWER 五月花
# 629
# ==================  19  ==================
# 【週期購】倍潔雅柔軟舒適抽取式衛生紙(150抽56包/箱)
# PASEO 倍潔雅
# 599

# %%
df.head()
# Out:
#                                     title           brand  price amount
# 0             【櫻花】超值新柔感抽取式衛生紙(150抽x84包/箱)                  1,699    799
# 1         【朵舒】超厚柔棉仔紙抽取式衛生紙(150抽x12包x6袋/箱)              朵舒  1,500    759
# 2  【MAY FLOWER 五月花】新柔韌抽取式衛生紙(130抽x12包x6袋)  MAY FLOWER 五月花  1,194    869
# 3           【Kleenex 舒潔】棉柔舒適抽取衛生紙110抽X72包      Kleenex 舒潔  1,599    955
# 4              【倍潔雅】花漾柔感抽取式衛生紙(150抽70包/箱)       PASEO 倍潔雅  1,200    749

# %%
df[0:20]
# Out:
#                                             title                   brand  \
# 0                     【櫻花】超值新柔感抽取式衛生紙(150抽x84包/箱)
# 1                 【朵舒】超厚柔棉仔紙抽取式衛生紙(150抽x12包x6袋/箱)                      朵舒
# 2          【MAY FLOWER 五月花】新柔韌抽取式衛生紙(130抽x12包x6袋)          MAY FLOWER 五月花
# 3                   【Kleenex 舒潔】棉柔舒適抽取衛生紙110抽X72包              Kleenex 舒潔
# 4                      【倍潔雅】花漾柔感抽取式衛生紙(150抽70包/箱)               PASEO 倍潔雅
# 5                【Kleenex 舒潔】柔韌潔淨抽取衛生紙 110抽x48包/箱              Kleenex 舒潔
# 6                     【五月花】新柔韌抽取式衛生紙(110抽x12包x6袋)          MAY FLOWER 五月花
# 7                     【春風】抽取式衛生紙-輕柔膚觸-100抽*24包*3串                      春風
# 8                  【朵舒】極細柔抽取式花紋衛生紙(200抽x12包x4袋/箱)                      朵舒
# 9                      【倍潔雅】花漾柔感抽取式衛生紙(150抽84包/箱)               PASEO 倍潔雅
# 10               【Kleenex 舒潔】柔韌潔淨抽取衛生紙 100抽x60包/箱              Kleenex 舒潔
# 11  【Kirkland Signature 科克蘭】三層抽取衛生紙 120張x24包x3串/箱  Kirkland Signature 科克蘭
# 12              【倍潔雅】好韌真3層抽取式衛生紙PEFC(100抽12包6袋/箱)               PASEO 倍潔雅
# 13                      【倍潔雅】花漾柔感抽取式衛生紙200抽x48包/箱               PASEO 倍潔雅
# 14                   【朵舒】舒適柔抽取式衛生紙(150抽x10包x8袋/箱)                      朵舒
# 15          【Kleenex 舒潔】頂級三層舒適竹炭萃取抽取衛生紙 90抽x30包/箱              Kleenex 舒潔
# 16                      【倍潔雅】柔軟舒適抽取式衛生紙150抽x60包/箱               PASEO 倍潔雅
# 17                【Kleenex 舒潔】絲絨舒膚抽取衛生紙110抽x64包/箱              Kleenex 舒潔
# 18                     【五月花】花園版抽取式衛生紙(100抽*8包*8袋)          MAY FLOWER 五月花
# 19                  【週期購】倍潔雅柔軟舒適抽取式衛生紙(150抽56包/箱)               PASEO 倍潔雅
#
#     price amount
# 0   1,699    799
# 1   1,500    759
# 2   1,194    869
# 3   1,599    955
# 4   1,200    749
# 5     899    619
# 6   1,014    869
# 7     829    679
# 8   1,300    669
# 9     899    859
# 10  1,299    689
# 11  1,399  1,359
# 12    799    759
# 13  1,500    689
# 14  1,600    829
# 15    899    525
# 16    659    629
# 17  1,299    789
# 18    899    629
# 19  1,399    599

# %%
# 切品名規格
# 加local date col
# 加節日折扣價
